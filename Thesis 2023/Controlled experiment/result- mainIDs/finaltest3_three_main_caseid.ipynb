# %%
#6 caseid. 4 cons  3 month.  6 customerr.  2 emp two month. 4 emp the third monthh 

from google.colab import drive
drive.mount('/content/gdrive')
# %cd /content/gdrive/MyDrive/Finalproject/thesis-newlog-2023/finaltest3/

# !pwd
# !pip install pm4py
# !pip install visualizer
# !pip install algorithm
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# /content/gdrive/MyDrive/Finalproject/thesis-newlog-2023/finaltest3
# /content/gdrive/MyDrive/Finalproject/thesis-newlog-2023/finaltest3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pm4py in /usr/local/lib/python3.8/dist-packages (2.5.2)
# Requirement already satisfied: intervaltree in /usr/local/lib/python3.8/dist-packages (from pm4py) (2.1.0)
# Requirement already satisfied: pydotplus in /usr/local/lib/python3.8/dist-packages (from pm4py) (2.0.2)
# Requirement already satisfied: lxml in /usr/local/lib/python3.8/dist-packages (from pm4py) (4.9.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.8/dist-packages (from pm4py) (3.0)
# Requirement already satisfied: cvxopt in /usr/local/lib/python3.8/dist-packages (from pm4py) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from pm4py) (1.22.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from pm4py) (3.5.3)
# Requirement already satisfied: pytz in /usr/local/lib/python3.8/dist-packages (from pm4py) (2022.7.1)
# Requirement already satisfied: stringdist in /usr/local/lib/python3.8/dist-packages (from pm4py) (1.0.9)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from pm4py) (1.7.3)
# Requirement already satisfied: deprecation in /usr/local/lib/python3.8/dist-packages (from pm4py) (2.1.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.8/dist-packages (from pm4py) (4.64.1)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.8/dist-packages (from pm4py) (0.10.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.8/dist-packages (from pm4py) (1.3.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from deprecation->pm4py) (23.0)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.8/dist-packages (from intervaltree->pm4py) (2.4.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->pm4py) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib->pm4py) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->pm4py) (8.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->pm4py) (4.38.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib->pm4py) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->pm4py) (1.4.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7->matplotlib->pm4py) (1.15.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: visualizer in /usr/local/lib/python3.8/dist-packages (0.0.10)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from visualizer) (2.2.0)
# Requirement already satisfied: wordcloud>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from visualizer) (1.8.2.2)
# Requirement already satisfied: matplotlib>=3.1.2 in /usr/local/lib/python3.8/dist-packages (from visualizer) (3.5.3)
# Requirement already satisfied: pandas>=0.25.3 in /usr/local/lib/python3.8/dist-packages (from visualizer) (1.3.5)
# Requirement already satisfied: scikit-learn>=0.21.3 in /usr/local/lib/python3.8/dist-packages (from visualizer) (1.0.2)
# Requirement already satisfied: seaborn>=0.9.0 in /usr/local/lib/python3.8/dist-packages (from visualizer) (0.11.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.1.2->visualizer) (2.8.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.1.2->visualizer) (1.22.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.1.2->visualizer) (23.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.1.2->visualizer) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.1.2->visualizer) (8.4.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.1.2->visualizer) (1.4.4)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.1.2->visualizer) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib>=3.1.2->visualizer) (4.38.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=0.25.3->visualizer) (2022.7.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.21.3->visualizer) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.21.3->visualizer) (1.2.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.21.3->visualizer) (1.7.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7->matplotlib>=3.1.2->visualizer) (1.15.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: algorithm in /usr/local/lib/python3.8/dist-packages (1.2.0)
# Requirement already satisfied: dependency-injection in /usr/local/lib/python3.8/dist-packages (from algorithm) (1.2.0)

# %%
import pandas as pd
import pm4py

df=pd.read_csv('/content/gdrive/MyDrive/Finalproject/thesis-newlog-2023/finaltest3/finaltest3-threemonth.csv')

# %%
df
# Out:
#       case:concept:name  CustomerID  BankerID  Loan Amount  Interest Rate  \
# 0                     1           6        73            0              0
# 1                     1           6        73            0              0
# 2                     1           6        73        38722              0
# 3                     1           6        73        38722              0
# 4                     1           6        73        38722              0
# ...                 ...         ...       ...          ...            ...
# 4740                735           4        71            0              0
# 4741                735           4        71        19207              0
# 4742                735           4        71        19207              0
# 4743                735           4        71        19207              0
# 4744                735           4        71        19207              0
#
#      lifecycle:transition                             Activity  EmpCntDa  \
# 0                7.1.2020                         Request Loan         0
# 1                7.1.2020           Check Employee Eligibility         0
# 2                7.1.2020  Record Loan Application Information         0
# 3                7.1.2020                Check Amount Legality         0
# 4                7.1.2020                    Client Assessment         0
# ...                   ...                                  ...       ...
# 4740            27.3.2020           Check Employee Eligibility         0
# 4741            27.3.2020  Record Loan Application Information         0
# 4742            27.3.2020                Check Amount Legality         0
# 4743            27.3.2020                    Client Assessment         0
# 4744            27.3.2020                       Cancel Request         0
#
#       CusToMo  EmpToMo  AVGIR      CusMoID     EmpMoID      EmpDayID
# 0           0        0   0.00  customer6-1  Banker73-1   Banker73-17
# 1           0        0   0.00  customer6-1  Banker73-1   Banker73-17
# 2           0        0   0.00  customer6-1  Banker73-1   Banker73-17
# 3           0        0   0.00  customer6-1  Banker73-1   Banker73-17
# 4           0        0   0.00  customer6-1  Banker73-1   Banker73-17
# ...       ...      ...    ...          ...         ...           ...
# 4740   194214   348289   4.96  customer4-3  Banker71-3  Banker71-327
# 4741   194214   348289   4.96  customer4-3  Banker71-3  Banker71-327
# 4742   194214   348289   4.96  customer4-3  Banker71-3  Banker71-327
# 4743   194214   348289   4.96  customer4-3  Banker71-3  Banker71-327
# 4744   194214   348289   4.96  customer4-3  Banker71-3  Banker71-327
#
# [4745 rows x 14 columns]

# %%
#Loan_ID

import pandas as pd
import pm4py
from pm4py.visualization.petri_net import visualizer
from pm4py.algo.decision_mining import algorithm as decision_mining
from pm4py.algo.evaluation.generalization import algorithm as generalization_evaluator
from pm4py.algo.evaluation.simplicity import algorithm as simplicity_evaluator



log_scv = pm4py.format_dataframe(df, case_id='case:concept:name', activity_key='Activity', timestamp_key='lifecycle:transition')
pm4py.write_xes(log_scv, '/content/gdrive/MyDrive/Finalproject/thesis-newlog-2023/finaltest3/ft3-loanID.xes')
log= pm4py.read_xes('/content/gdrive/MyDrive/Finalproject/thesis-newlog-2023/finaltest3/ft3-loanID.xes')


#Inductive miner: 
net, im, fm = pm4py.discover_petri_net_inductive(log)
gviz = visualizer.apply(net, im, fm, parameters={visualizer.Variants.WO_DECORATION.value.Parameters.DEBUG: True})
pm4py.view_petri_net(net, im, fm)
#Instance spanning constraints:
net, im, fm = decision_mining.create_data_petri_nets_with_decisions(log, net, im, fm)
gviz = visualizer.apply(net, im, fm, parameters={visualizer.Variants.WO_DECORATION.value.Parameters.DEBUG: True})
pm4py.view_petri_net(net, im, fm)

#Guards:
for t in net.transitions:
    if "guard" in t.properties:
        print("")
        print(t)
        print(t.properties["guard"])




fitness = pm4py.fitness_alignments(log, net, im, fm)
print("the fitness is:" , fitness)
prec = pm4py.precision_alignments(log, net, im, fm)
print("the precision is ", prec)
# Out:
# /usr/local/lib/python3.8/dist-packages/pm4py/visualization/decisiontree/__init__.py:21: UserWarning: The decisiontree visualizer will be removed in a future release (use Scikit Learn instead).
#   warnings.warn("The decisiontree visualizer will be removed in a future release (use Scikit Learn instead).")
# /usr/local/lib/python3.8/dist-packages/pm4py/algo/decision_mining/__init__.py:21: UserWarning: The decision_mining package will be removed in a future release.
#   warnings.warn("The decision_mining package will be removed in a future release.")
# <ipython-input-4-e38a6e62e104>:12: DeprecatedWarning: format_dataframe is deprecated as of 2.3.0 and will be removed in 3.0.0. the format_dataframe function does not need application anymore.
#   log_scv = pm4py.format_dataframe(df, case_id='case:concept:name', activity_key='Activity', timestamp_key='lifecycle:transition')
# exporting log, completed traces ::   0%|          | 0/735 [00:00<?, ?it/s]
# /usr/local/lib/python3.8/dist-packages/pm4py/util/dt_parsing/parser.py:76: UserWarning: ISO8601 strings are not fully supported with strpfromiso for Python versions below 3.11
#   warnings.warn(
# parsing log, completed traces ::   0%|          | 0/735 [00:00<?, ?it/s]
# replaying log with TBR, completed variants ::   0%|          | 0/4 [00:00<?, ?it/s]
# replaying log with TBR, completed variants ::   0%|          | 0/4 [00:00<?, ?it/s]
# replaying log with TBR, completed variants ::   0%|          | 0/4 [00:00<?, ?it/s]
# (bfe86e20-0335-4155-b2d2-db19a083ab4c, 'Record Loan Application Information')
# (EmpCntDa <= 2.50)
#
# (skip_1, None)
# (EmpCntDa >  2.50)
#
# (2c79d641-0743-4dd0-97d7-a68ba8cbe21d, 'Cancel Request')
# (Activity_Cancel Request <= 0.50 && EmpToMo <= 14686.00 && Interest Rate >  6.50) || (Activity_Cancel Request <= 0.50 && EmpToMo >  14686.00 && @@index <= 388.00 && @@case_index >  50.50) || (Activity_Cancel Request >  0.50)
#
# (16a35e19-0a62-4117-a2c2-f227097b3b88, 'Sign Loan Contract')
# (Activity_Cancel Request <= 0.50 && EmpToMo <= 14686.00 && Interest Rate <= 6.50) || (Activity_Cancel Request <= 0.50 && EmpToMo >  14686.00 && @@index <= 388.00 && @@case_index <= 50.50) || (Activity_Cancel Request <= 0.50 && EmpToMo >  14686.00 && @@index >  388.00)
# aligning log, completed variants ::   0%|          | 0/4 [00:00<?, ?it/s]
# the fitness is: {'percFitTraces': 100.0, 'averageFitness': 1.0, 'percentage_of_fitting_traces': 100.0, 'average_trace_fitness': 1.0, 'log_fitness': 0.9999917410945366}
# computing precision with alignments, completed variants ::   0%|          | 0/8 [00:00<?, ?it/s]
# the precision is  0.8790171739500086

# %%
#Customer_ID

import pandas as pd
import pm4py
from pm4py.visualization.petri_net import visualizer
from pm4py.algo.decision_mining import algorithm as decision_mining
from pm4py.algo.evaluation.generalization import algorithm as generalization_evaluator
from pm4py.algo.evaluation.simplicity import algorithm as simplicity_evaluator



log_scv = pm4py.format_dataframe(df, case_id='CustomerID', activity_key='Activity', timestamp_key='lifecycle:transition')
pm4py.write_xes(log_scv, '/content/gdrive/MyDrive/Finalproject/thesis-newlog-2023/finaltest3/ft3-customerID.xes')
log= pm4py.read_xes('/content/gdrive/MyDrive/Finalproject/thesis-newlog-2023/finaltest3/ft3-customerID.xes')


#Inductive miner: 
net, im, fm = pm4py.discover_petri_net_inductive(log)
gviz = visualizer.apply(net, im, fm, parameters={visualizer.Variants.WO_DECORATION.value.Parameters.DEBUG: True})
pm4py.view_petri_net(net, im, fm)
#Instance spanning constraints:
net, im, fm = decision_mining.create_data_petri_nets_with_decisions(log, net, im, fm)
gviz = visualizer.apply(net, im, fm, parameters={visualizer.Variants.WO_DECORATION.value.Parameters.DEBUG: True})
pm4py.view_petri_net(net, im, fm)

#Guards:
for t in net.transitions:
    if "guard" in t.properties:
        print("")
        print(t)
        print(t.properties["guard"])




fitness = pm4py.fitness_alignments(log, net, im, fm)
print("the fitness is:" , fitness)
prec = pm4py.precision_alignments(log, net, im, fm)
print("the precision is ", prec)
# Out:
# <ipython-input-6-87fc6daeb85c>:12: DeprecatedWarning: format_dataframe is deprecated as of 2.3.0 and will be removed in 3.0.0. the format_dataframe function does not need application anymore.
#   log_scv = pm4py.format_dataframe(df, case_id='CustomerID', activity_key='Activity', timestamp_key='lifecycle:transition')
# exporting log, completed traces ::   0%|          | 0/6 [00:00<?, ?it/s]
# parsing log, completed traces ::   0%|          | 0/6 [00:00<?, ?it/s]
# replaying log with TBR, completed variants ::   0%|          | 0/6 [00:00<?, ?it/s]
# replaying log with TBR, completed variants ::   0%|          | 0/6 [00:00<?, ?it/s]
# replaying log with TBR, completed variants ::   0%|          | 0/6 [00:00<?, ?it/s]
# replaying log with TBR, completed variants ::   0%|          | 0/6 [00:00<?, ?it/s]
# (6e6b339d-273a-4f64-bcfb-dc2391774dab, 'Record Loan Application Information')
# (EmpCntDa <= 2.50)
#
# (cc692be6-618f-450d-8a01-54604c239c36, 'Cancel Request')
# (Activity_Cancel Request <= 0.50 && EmpToMo <= 14686.00 && Interest Rate >  6.50) || (Activity_Cancel Request <= 0.50 && EmpToMo >  14686.00 && EmpToMo >  423081.50 && EmpToMo <= 433418.50 && CusToMo >  126083.50) || (Activity_Cancel Request >  0.50)
#
# (31daf1b3-1be4-4855-aa1e-6e9aa0d8b6f2, 'Sign Loan Contract')
# (Activity_Cancel Request <= 0.50 && EmpToMo <= 14686.00 && Interest Rate <= 6.50) || (Activity_Cancel Request <= 0.50 && EmpToMo >  14686.00 && EmpToMo <= 423081.50) || (Activity_Cancel Request <= 0.50 && EmpToMo >  14686.00 && EmpToMo >  423081.50 && EmpToMo <= 433418.50 && CusToMo <= 126083.50) || (Activity_Cancel Request <= 0.50 && EmpToMo >  14686.00 && EmpToMo >  423081.50 && EmpToMo >  433418.50)
#
# (skip_7, None)
# (@@index <= 4741.00 && AVGIR <= 5.43 && EmpMoID_Banker72-3 <= 0.50 && @@index <= 3834.00) || (@@index <= 4741.00 && AVGIR <= 5.43 && EmpMoID_Banker72-3 <= 0.50 && @@index >  3834.00 && CustomerID >  5.50) || (@@index <= 4741.00 && AVGIR <= 5.43 && EmpMoID_Banker72-3 >  0.50 && AVGIR <= 3.98 && AVGIR <= 3.95 && EmpToMo <= 248942.00) || (@@index <= 4741.00 && AVGIR <= 5.43 && EmpMoID_Banker72-3 >  0.50 && AVGIR <= 3.98 && AVGIR <= 3.95 && EmpToMo >  248942.00 && @@index <= 2161.50) || (@@index <= 4741.00 && AVGIR <= 5.43 && EmpMoID_Banker72-3 >  0.50 && AVGIR <= 3.98 && AVGIR <= 3.95 && EmpToMo >  248942.00 && @@index >  2161.50 && CusToMo >  196112.00) || (@@index <= 4741.00 && AVGIR <= 5.43 && EmpMoID_Banker72-3 >  0.50 && AVGIR >  3.98) || (@@index <= 4741.00 && AVGIR >  5.43 && EmpToMo <= 224951.00)
#
# (skip_5, None)
# (EmpCntDa >  2.50)
#
# (skip_8, None)
# (@@index <= 4741.00 && AVGIR <= 5.43 && EmpMoID_Banker72-3 <= 0.50 && @@index >  3834.00 && CustomerID <= 5.50) || (@@index <= 4741.00 && AVGIR <= 5.43 && EmpMoID_Banker72-3 >  0.50 && AVGIR <= 3.98 && AVGIR <= 3.95 && EmpToMo >  248942.00 && @@index >  2161.50 && CusToMo <= 196112.00) || (@@index <= 4741.00 && AVGIR <= 5.43 && EmpMoID_Banker72-3 >  0.50 && AVGIR <= 3.98 && AVGIR >  3.95) || (@@index <= 4741.00 && AVGIR >  5.43 && EmpToMo >  224951.00) || (@@index >  4741.00)
# aligning log, completed variants ::   0%|          | 0/6 [00:00<?, ?it/s]
# the fitness is: {'percFitTraces': 100.0, 'averageFitness': 1.0, 'percentage_of_fitting_traces': 100.0, 'average_trace_fitness': 1.0, 'log_fitness': 0.9999723913604232}
# computing precision with alignments, completed variants ::   0%|          | 0/4615 [00:00<?, ?it/s]
# the precision is  0.7606276519093748

# %%
#employeeID

import pandas as pd
import pm4py
from pm4py.visualization.petri_net import visualizer
from pm4py.algo.decision_mining import algorithm as decision_mining
from pm4py.algo.evaluation.generalization import algorithm as generalization_evaluator
from pm4py.algo.evaluation.simplicity import algorithm as simplicity_evaluator



log_scv = pm4py.format_dataframe(df, case_id='BankerID', activity_key='Activity', timestamp_key='lifecycle:transition')
pm4py.write_xes(log_scv, '/content/gdrive/MyDrive/Finalproject/thesis-newlog-2023/finaltest3/ft3-employeeID.xes')
log= pm4py.read_xes('/content/gdrive/MyDrive/Finalproject/thesis-newlog-2023/finaltest3/ft3-employeeID.xes')


#Inductive miner: 
net, im, fm = pm4py.discover_petri_net_inductive(log)
gviz = visualizer.apply(net, im, fm, parameters={visualizer.Variants.WO_DECORATION.value.Parameters.DEBUG: True})
pm4py.view_petri_net(net, im, fm)
#Instance spanning constraints:
net, im, fm = decision_mining.create_data_petri_nets_with_decisions(log, net, im, fm)
gviz = visualizer.apply(net, im, fm, parameters={visualizer.Variants.WO_DECORATION.value.Parameters.DEBUG: True})
pm4py.view_petri_net(net, im, fm)

#Guards:
for t in net.transitions:
    if "guard" in t.properties:
        print("")
        print(t)
        print(t.properties["guard"])




fitness = pm4py.fitness_alignments(log, net, im, fm)
print("the fitness is:" , fitness)
prec = pm4py.precision_alignments(log, net, im, fm)
print("the precision is ", prec)
# Out:
# <ipython-input-4-6fdcd369751f>:12: DeprecatedWarning: format_dataframe is deprecated as of 2.3.0 and will be removed in 3.0.0. the format_dataframe function does not need application anymore.
#   log_scv = pm4py.format_dataframe(df, case_id='BankerID', activity_key='Activity', timestamp_key='lifecycle:transition')
# exporting log, completed traces ::   0%|          | 0/4 [00:00<?, ?it/s]
# /usr/local/lib/python3.8/dist-packages/pm4py/util/dt_parsing/parser.py:76: UserWarning: ISO8601 strings are not fully supported with strpfromiso for Python versions below 3.11
#   warnings.warn(
# parsing log, completed traces ::   0%|          | 0/4 [00:00<?, ?it/s]
# replaying log with TBR, completed variants ::   0%|          | 0/4 [00:00<?, ?it/s]
# replaying log with TBR, completed variants ::   0%|          | 0/4 [00:00<?, ?it/s]
# replaying log with TBR, completed variants ::   0%|          | 0/4 [00:00<?, ?it/s]
# replaying log with TBR, completed variants ::   0%|          | 0/4 [00:00<?, ?it/s]
# (904310d5-2dca-4139-b131-2fecf527b172, 'Record Loan Application Information')
# (EmpCntDa <= 2.50)
#
# (1a539c42-2044-416c-aa4f-83afd8694fb5, 'Cancel Request')
# (Activity_Check Interest Rate Average <= 0.50) || (Activity_Check Interest Rate Average >  0.50 && EmpToMo <= 14686.00 && Interest Rate >  6.50) || (Activity_Check Interest Rate Average >  0.50 && EmpToMo >  14686.00 && EmpMoID_Banker72-1 >  0.50 && Interest Rate >  6.50 && EmpToMo >  389185.00)
#
# (skip_8, None)
# (@@index <= 4741.00 && Loan Amount <= 15852.00 && Loan Amount <= 15737.50 && Loan Amount >  10980.00 && Loan Amount <= 11085.00) || (@@index <= 4741.00 && Loan Amount <= 15852.00 && Loan Amount <= 15737.50 && Loan Amount >  10980.00 && Loan Amount >  11085.00 && AVGIR >  5.34 && AVGIR <= 5.54) || (@@index <= 4741.00 && Loan Amount <= 15852.00 && Loan Amount >  15737.50) || (@@index >  4741.00)
#
# (skip_5, None)
# (EmpCntDa >  2.50)
#
# (d0ebbfe4-46ba-48c4-88d2-f608e60320e3, 'Sign Loan Contract')
# (Activity_Check Interest Rate Average >  0.50 && EmpToMo <= 14686.00 && Interest Rate <= 6.50) || (Activity_Check Interest Rate Average >  0.50 && EmpToMo >  14686.00 && EmpMoID_Banker72-1 <= 0.50) || (Activity_Check Interest Rate Average >  0.50 && EmpToMo >  14686.00 && EmpMoID_Banker72-1 >  0.50 && Interest Rate <= 6.50) || (Activity_Check Interest Rate Average >  0.50 && EmpToMo >  14686.00 && EmpMoID_Banker72-1 >  0.50 && Interest Rate >  6.50 && EmpToMo <= 389185.00)
#
# (skip_7, None)
# (@@index <= 4741.00 && Loan Amount <= 15852.00 && Loan Amount <= 15737.50 && Loan Amount <= 10980.00) || (@@index <= 4741.00 && Loan Amount <= 15852.00 && Loan Amount <= 15737.50 && Loan Amount >  10980.00 && Loan Amount >  11085.00 && AVGIR <= 5.34) || (@@index <= 4741.00 && Loan Amount <= 15852.00 && Loan Amount <= 15737.50 && Loan Amount >  10980.00 && Loan Amount >  11085.00 && AVGIR >  5.34 && AVGIR >  5.54) || (@@index <= 4741.00 && Loan Amount >  15852.00)
# aligning log, completed variants ::   0%|          | 0/4 [00:00<?, ?it/s]
# the fitness is: {'percFitTraces': 100.0, 'averageFitness': 1.0, 'percentage_of_fitting_traces': 100.0, 'average_trace_fitness': 1.0, 'log_fitness': 0.9999723985774904}
# computing precision with alignments, completed variants ::   0%|          | 0/4715 [00:00<?, ?it/s]
